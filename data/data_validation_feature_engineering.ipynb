# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("cleaned_data.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0                      title      price  \
# 0               0           0            111A DEPOT ROAD   970000.0
# 1               1           1        405 SIN MING AVENUE  1050000.0
# 2               2           2      61C STRATHMORE AVENUE   820000.0
# 3               3           3               87 ZION ROAD  1158000.0
# 4               4           4             50 DORSET ROAD   615000.0
# ..            ...         ...                        ...        ...
# 992           992         992    180A RIVERVALE CRESCENT   530000.0
# 993           993         993  439A SENGKANG WEST AVENUE   708000.0
# 994           994         994       173 HOUGANG AVENUE 1   628000.0
# 995           995         995       266B COMPASSVALE BOW   710000.0
# 996           996         996     204B COMPASSVALE DRIVE   630000.0
#
#         n_rooms             area  year  price_per_sqft  size_sqft  \
# 0    HDB 5-Room      Bukit Merah  2004           784.0     1238.0
# 1    HDB 5-Room           Bishan  1985           813.0     1292.0
# 2    HDB 3-Room       Queenstown  2010          1104.0      743.0
# 3    HDB 5-Room      Bukit Merah  1974           944.0     1227.0
# 4    HDB 3-Room  Kallang/Whampoa  1978           697.0      882.0
# ..          ...              ...   ...             ...        ...
# 992  HDB 3-Room         Sengkang  2012           735.0      721.0
# 993  HDB 4-Room         Sengkang  2009           700.0     1011.0
# 994  HDB 4-Room          Hougang  1996           572.0     1098.0
# 995  HDB 4-Room       North-east  2010           717.0      990.0
# 996  HDB 4-Room         Sengkang  1999           650.0      969.0
#
#                 road_name  n_bedrooms  n_bathrooms      region scraped_date
# 0              Depot Road           3            2     central   2025-03-27
# 1         Sin Ming Avenue           3            2     central   2025-03-27
# 2       Strathmore Avenue           2            2     central   2025-03-27
# 3               Zion Road           3            2     central   2025-03-27
# 4             Dorset Road           2            2     central   2025-03-27
# ..                    ...         ...          ...         ...          ...
# 992    Rivervale Crescent           2            2  north-east   2025-03-19
# 993  Sengkang West Avenue           3            2  north-east   2025-03-19
# 994      Hougang Avenue 1           3            2  north-east   2025-03-19
# 995       Compassvale Bow           3            2  north-east   2025-03-19
# 996     Compassvale Drive           3            2  north-east   2025-03-19
#
# [997 rows x 14 columns]

# %% [markdown]
# ### Validatation Checks

# %%
#--- Data Validation-----
df.isnull().sum()
# Out:
# Unnamed: 0.1      0
# Unnamed: 0        0
# title             0
# price             0
# n_rooms           0
# area              0
# year              0
# price_per_sqft    0
# size_sqft         0
# road_name         0
# n_bedrooms        0
# n_bathrooms       0
# region            0
# scraped_date      0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0.1        int64
# Unnamed: 0          int64
# title              object
# price             float64
# n_rooms            object
# area               object
# year                int64
# price_per_sqft    float64
# size_sqft         float64
# road_name          object
# n_bedrooms          int64
# n_bathrooms         int64
# region             object
# scraped_date       object
# dtype: object

# %%
df['price'].describe()
# Out:
# count    9.970000e+02
# mean     6.645799e+05
# std      2.566384e+05
# min      3.000000e+05
# 25%      5.200000e+05
# 50%      6.180000e+05
# 75%      7.300000e+05
# max      4.500000e+06
# Name: price, dtype: float64

# %%
df['year'].unique()
# Out:
# array([2004, 1985, 2010, 1974, 1978, 1982, 1995, 1994, 1979, 1997, 1971,
#        1976, 1977, 2019, 2018, 1999, 1990, 2000, 2003, 1972, 1969, 1987,
#        1998, 2016, 1986, 1967, 1970, 2017, 1980, 1975, 2021, 1983, 1993,
#        1973, 1949, 2015, 1963, 1959, 2011, 2001, 2012, 2005, 1965, 1988,
#        1984, 2007, 1964, 1968, 1991, 2020, 2009, 1937, 2002, 1996, 1981,
#        2013, 2008, 1989, 2014, 1992, 2006, 1962])

# %%
df['size_sqft'].describe()
# Out:
# count      997.000000
# mean       960.221665
# std        374.968703
# min         10.000000
# 25%        786.000000
# 50%        990.000000
# 75%       1076.000000
# max      11119.000000
# Name: size_sqft, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['n_rooms'].value_counts()
# Out:
# n_rooms
# HDB 4-Room                     592
# HDB 3-Room                     291
# HDB 5-Room                      56
# HDB 4PA (Premium Apartment)     52
# HDB 3PA (Premium Apartment)      3
# HDB 5PA (Premium Apartment)      3
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# central       200
# north         200
# west          199
# east          199
# north-east    199
# Name: count, dtype: int64

# %%
df['area'].value_counts()
# Out:
# area
# Jurong West        85
# Sengkang           66
# Tampines           62
# Punggol            59
# Clementi           52
# Bedok              46
# Queenstown         44
# Yishun             44
# Jurong East        42
# Hougang            42
# Toa Payoh          39
# Bukit Merah        38
# Woodlands          36
# Kallang/Whampoa    32
# Geylang            32
# Bukit Batok        31
# Ang Mo Kio         29
# Bukit Panjang      28
# Sembawang          27
# Bishan             26
# East               26
# Serangoon          24
# Choa Chu Kang      20
# North              14
# West               12
# Pasir Ris          10
# Central             8
# North-east          8
# Marine Parade       7
# Central Area        6
# Bukit Timah         2
# Name: count, dtype: int64

# %%
df[(df['n_bedrooms'] <= 0) | (df['n_bathrooms'] <= 0)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, title, price, n_rooms, area, year, price_per_sqft, size_sqft, road_name, n_bedrooms, n_bathrooms, region, scraped_date]
# Index: []

# %%
df['computed_price_psf'] = df['price'] / df['size_sqft']
df[['price_per_sqft', 'computed_price_psf']].head()
# Out:
#    price_per_sqft  computed_price_psf
# 0           784.0          783.521809
# 1           813.0          812.693498
# 2          1104.0         1103.633917
# 3           944.0          943.765281
# 4           697.0          697.278912

# %%
df.drop(columns=['computed_price_psf'], inplace=True)

# %% [markdown]
# ###Feature Engineering

# %%
df['scraped_date'] = pd.to_datetime(df['scraped_date'], errors='coerce')
df['scraped_date'].describe()
# Out:
# count                              997
# mean     2025-03-11 09:31:57.352056320
# min                2025-02-25 00:00:00
# 25%                2025-03-03 00:00:00
# 50%                2025-03-10 00:00:00
# 75%                2025-03-21 00:00:00
# max                2025-03-27 00:00:00
# Name: scraped_date, dtype: object

# %%
df = df.rename(columns={'year': 'build_year'})

# %%
# --- Feature Engineering ---

# 1. Flat Age
df['flat_age'] = 2025 - df['build_year']

# 2. Lease Remaining (assuming 99-year HDB lease)
df['lease_remaining'] = 99 - df['flat_age']

# 3. Price per Bedroom
df['price_per_bedroom'] = df['price'] / df['n_bedrooms']

# 5. Size per Room
df['size_per_room'] = df['size_sqft'] / df['n_bedrooms']

# 6. Bedroom to Bathroom Ratio
df['bed_bath_ratio'] = df['n_bedrooms'] / df['n_bathrooms']

# 7. Extract scraped month and year
df['scraped_date'] = pd.to_datetime(df['scraped_date'])
df['scraped_month'] = df['scraped_date'].dt.month
df['scraped_year'] = df['scraped_date'].dt.year

# 8. (Optional) Drop unused columns if needed
df = df.drop(columns=["Unnamed: 0", "Unnamed: 0.1"])

#For better visibility to the model, need to flag it
df['is_central'] = (df['region'].str.lower() == 'central').astype(int)

# Define mature towns in Singapore
mature_towns = [
    'Ang Mo Kio', 'Bedok', 'Bishan', 'Bukit Merah', 'Bukit Timah', 'Central Area',
    'Clementi', 'Geylang', 'Kallang/Whampoa', 'Marine Parade',
    'Pasir Ris', 'Queenstown', 'Serangoon', 'Tampines', 'Toa Payoh'
]

# Add a binary feature: 1 if town is mature, 0 otherwise
df['is_mature_town'] = df['area'].isin(mature_towns).astype(int)

#This captures how older + larger flats behave in pricing.
	#	Some old flats may still be big and valuable.
	#	Others may be old and small → lower value.
df['age_size_interaction'] = df['flat_age'] * df['size_sqft']

# This tells the model:
	# A flat with 90 years lease and $800 psf is very different from one with 30 years at $800 psf.
	# Lease affects how much the per sqft price matters.
df['lease_price_interaction'] = df['lease_remaining'] * df['price_per_sqft']


# Display the first few rows
print(df.head())
# Out:
#                    title      price     n_rooms             area  build_year  \
# 0        111A DEPOT ROAD   970000.0  HDB 5-Room      Bukit Merah        2004
# 1    405 SIN MING AVENUE  1050000.0  HDB 5-Room           Bishan        1985
# 2  61C STRATHMORE AVENUE   820000.0  HDB 3-Room       Queenstown        2010
# 3           87 ZION ROAD  1158000.0  HDB 5-Room      Bukit Merah        1974
# 4         50 DORSET ROAD   615000.0  HDB 3-Room  Kallang/Whampoa        1978
#
#    price_per_sqft  size_sqft          road_name  n_bedrooms  n_bathrooms  ...  \
# 0           784.0     1238.0         Depot Road           3            2  ...
# 1           813.0     1292.0    Sin Ming Avenue           3            2  ...
# 2          1104.0      743.0  Strathmore Avenue           2            2  ...
# 3           944.0     1227.0          Zion Road           3            2  ...
# 4           697.0      882.0        Dorset Road           2            2  ...
#
#   lease_remaining price_per_bedroom  size_per_room  bed_bath_ratio  \
# 0              78     323333.333333     412.666667             1.5
# 1              59     350000.000000     430.666667             1.5
# 2              84     410000.000000     371.500000             1.0
# 3              48     386000.000000     409.000000             1.5
# 4              52     307500.000000     441.000000             1.0
#
#    scraped_month  scraped_year  is_central  is_mature_town  \
# 0              3          2025           1               1
# 1              3          2025           1               1
# 2              3          2025           1               1
# 3              3          2025           1               1
# 4              3          2025           1               1
#
#    age_size_interaction  lease_price_interaction
# 0               25998.0                  61152.0
# 1               51680.0                  47967.0
# 2               11145.0                  92736.0
# 3               62577.0                  45312.0
# 4               41454.0                  36244.0
#
# [5 rows x 23 columns]

# %%
df
# Out:
#                          title      price     n_rooms             area  \
# 0              111A DEPOT ROAD   970000.0  HDB 5-Room      Bukit Merah
# 1          405 SIN MING AVENUE  1050000.0  HDB 5-Room           Bishan
# 2        61C STRATHMORE AVENUE   820000.0  HDB 3-Room       Queenstown
# 3                 87 ZION ROAD  1158000.0  HDB 5-Room      Bukit Merah
# 4               50 DORSET ROAD   615000.0  HDB 3-Room  Kallang/Whampoa
# ..                         ...        ...         ...              ...
# 992    180A RIVERVALE CRESCENT   530000.0  HDB 3-Room         Sengkang
# 993  439A SENGKANG WEST AVENUE   708000.0  HDB 4-Room         Sengkang
# 994       173 HOUGANG AVENUE 1   628000.0  HDB 4-Room          Hougang
# 995       266B COMPASSVALE BOW   710000.0  HDB 4-Room       North-east
# 996     204B COMPASSVALE DRIVE   630000.0  HDB 4-Room         Sengkang
#
#      build_year  price_per_sqft  size_sqft             road_name  n_bedrooms  \
# 0          2004           784.0     1238.0            Depot Road           3
# 1          1985           813.0     1292.0       Sin Ming Avenue           3
# 2          2010          1104.0      743.0     Strathmore Avenue           2
# 3          1974           944.0     1227.0             Zion Road           3
# 4          1978           697.0      882.0           Dorset Road           2
# ..          ...             ...        ...                   ...         ...
# 992        2012           735.0      721.0    Rivervale Crescent           2
# 993        2009           700.0     1011.0  Sengkang West Avenue           3
# 994        1996           572.0     1098.0      Hougang Avenue 1           3
# 995        2010           717.0      990.0       Compassvale Bow           3
# 996        1999           650.0      969.0     Compassvale Drive           3
#
#      n_bathrooms  ... lease_remaining price_per_bedroom  size_per_room  \
# 0              2  ...              78     323333.333333     412.666667
# 1              2  ...              59     350000.000000     430.666667
# 2              2  ...              84     410000.000000     371.500000
# 3              2  ...              48     386000.000000     409.000000
# 4              2  ...              52     307500.000000     441.000000
# ..           ...  ...             ...               ...            ...
# 992            2  ...              86     265000.000000     360.500000
# 993            2  ...              83     236000.000000     337.000000
# 994            2  ...              70     209333.333333     366.000000
# 995            2  ...              84     236666.666667     330.000000
# 996            2  ...              73     210000.000000     323.000000
#
#      bed_bath_ratio  scraped_month  scraped_year  is_central  is_mature_town  \
# 0               1.5              3          2025           1               1
# 1               1.5              3          2025           1               1
# 2               1.0              3          2025           1               1
# 3               1.5              3          2025           1               1
# 4               1.0              3          2025           1               1
# ..              ...            ...           ...         ...             ...
# 992             1.0              3          2025           0               0
# 993             1.5              3          2025           0               0
# 994             1.5              3          2025           0               0
# 995             1.5              3          2025           0               0
# 996             1.5              3          2025           0               0
#
#      age_size_interaction  lease_price_interaction
# 0                 25998.0                  61152.0
# 1                 51680.0                  47967.0
# 2                 11145.0                  92736.0
# 3                 62577.0                  45312.0
# 4                 41454.0                  36244.0
# ..                    ...                      ...
# 992                9373.0                  63210.0
# 993               16176.0                  58100.0
# 994               31842.0                  40040.0
# 995               14850.0                  60228.0
# 996               25194.0                  47450.0
#
# [997 rows x 23 columns]

# %%
#Not done : to be done just before model training. Pending normalisation as well.
# One-hot encode n_rooms
#df = pd.get_dummies(df, columns=['n_rooms'], prefix='layout', drop_first=False)

# %%
# Save enhanced dataset (optional)
df.to_csv("enhanced_data.csv", index=False)
